# %%
import pandas as pd
import os,re,sys
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
os.chdir('C:/Users/RathoreA/Downloads/he_hdfc/DataSet/')

# %%
traindf=pd.read_csv('Train.csv')
testdf=pd.read_csv('Test.csv')
submissiondf=pd.read_csv('Sample_submission.csv')
# Out:
# c:\users\rathorea\appdata\local\continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (746,835) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# c:\users\rathorea\appdata\local\continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (700,731,740,752,761,789,811,820,829,841,850) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
traindf.head()
# Out:
#         Col1  Col2          Col3          Col4          Col5          Col6  \
# 0    RIGHGSN     1  1.086711e+04  8.648345e+03  1.576618e+04  2.890466e+04
# 1  RIMHI5ZGP     0  2.584312e+05  2.179633e+05  1.866287e+05  1.866287e+05
# 2  RIHOG1SZU     0  1.459355e+07  1.260060e+07  1.100315e+07  1.010315e+07
# 3  RIHOLMQWU     0  6.727043e+05  8.181116e+05  6.794893e+05  6.794893e+05
# 4  RIHO584ET     0 -1.218742e+06 -3.005361e+06 -1.666241e+05 -2.403574e+06
#
#            Col7          Col8          Col9         Col10   ...     Col2388  \
# 0  5.273655e+03  2.346153e+04  1.285597e+04  2.871509e+04   ...           0
# 1  2.154519e+05  1.923615e+05  1.726538e+05  1.666974e+05   ...           0
# 2  1.879882e+07  1.514035e+07  5.320778e+06  6.906324e+06   ...           0
# 3  8.257254e+05  7.605803e+05  3.577134e+05  4.236612e+05   ...           0
# 4  2.583183e+06  2.086546e+06  5.938358e+06  5.446532e+06   ...           0
#
# ...

# %%
traindf.shape
# Out:
# (17521, 2395)

# %%
traindf.describe()
# Out:
#                Col2          Col3          Col4          Col5          Col6  \
# count  17521.000000  1.752100e+04  1.752100e+04  1.752100e+04  1.752100e+04
# mean       0.100508  3.158967e+04  2.046540e+04  2.502937e+04  2.789385e+04
# std        0.300685  7.612897e+05  7.136908e+05  6.018207e+05  6.091245e+05
# min        0.000000 -8.555719e+07 -8.555719e+07 -7.011955e+07 -7.100920e+07
# 25%        0.000000  2.742337e+03  2.007863e+03  1.857013e+03  2.562647e+03
# 50%        0.000000  9.308060e+03  6.642857e+03  6.236503e+03  8.464355e+03
# 75%        0.000000  3.053873e+04  2.156093e+04  2.068154e+04  2.773849e+04
# max        1.000000  1.459355e+07  1.288980e+07  1.478068e+07  1.178075e+07
#
#                Col7          Col8          Col9         Col10         Col11  \
# count  1.752100e+04  1.752100e+04  1.752100e+04  1.752100e+04  1.752100e+04
# mean   2.597734e+04  3.302600e+04  2.912693e+04  2.971069e+04  3.617392e+04
# ...

# %%
def nullvaluesfinder(df):
    nullcolumns=df.columns[df.isnull().any()].tolist()
    nullcoldf=pd.DataFrame(df[nullcolumns].isnull().sum()/len(df)*100).reset_index()
    nullcoldf.columns=['colname','missingpercentage']
    return nullcoldf

# %%
nullcoldf=nullvaluesfinder(traindf)
#nullcolumns=traindf.columns[traindf.isnull().any()].tolist()
#nullcoldf=pd.DataFrame(traindf[nullcolumns].isnull().sum()/len(traindf)*100).reset_index()
#nullcoldf.columns=['colname','missingpercentage']

# %%
nullcoldf.head()
# Out:
#   colname  missingpercentage
# 0   Col13           7.128589
# 1   Col14           7.100051
# 2   Col15           7.111466
# 3   Col16           7.094344
# 4   Col17           8.389932

# %%
columns2bedeleted=nullcoldf[nullcoldf['missingpercentage']>=50]['colname'].tolist()

# %%
# dropping columns

columns2bekept=[col for col in traindf.columns if col not in columns2bedeleted]

# %%
traindf2=traindf[columns2bekept]

# %%
nullvaluesfinder(traindf2).shape,traindf2.shape
# Out:
# ((537, 2), (17521, 2173))

# %%
nullvaluesfinder(traindf2)
# Out:
#      colname  missingpercentage
# 0      Col13           7.128589
# 1      Col14           7.100051
# 2      Col15           7.111466
# 3      Col16           7.094344
# 4      Col17           8.389932
# 5      Col18          16.323269
# 6      Col21           7.082929
# 7      Col22           7.100051
# 8      Col23           7.094344
# 9      Col24           7.111466
# 10     Col27           3.892472
# 11     Col42          10.113578
# 12     Col43          10.124993
# 13     Col92           8.110268
# 14     Col93          10.655784
# 15     Col94          19.644997
# 16     Col95          35.956852
# 17     Col96          24.239484
# 18     Col98          29.199247
# 19    Col100          34.141887
# 20    Col101          32.412534
# 21    Col102          40.243137
# 22    Col103          42.982706
# 23    Col104          45.727984
# 24    Col106           8.115975
# 25    Col107          10.752811
# 26    Col108          22.179099
# 27    Col109          36.179442
# ...
